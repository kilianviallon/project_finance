# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
plt.style.use('default')
# %matplotlib inline

# %%
df1 = pd.read_csv('df1.txt', index_col = 0)
df2 = pd.read_csv('df2.txt')
df3 = pd.read_csv("df3.txt")

# %%
df1.plot(kind = 'hist')
plt.show()

# %%
mcdon = pd.read_csv('mcdonalds.csv', index_col = 'Date')
mcdon.head()
# Out:
#             Adj. Close  Adj. Volume
# Date
# 1970-01-02    0.209761    2825604.0
# 1970-01-05    0.213316    2210449.5
# 1970-01-06    0.214501    1951168.5
# 1970-01-07    0.213316    2728768.5
# 1970-01-08    0.213316    2242404.0

# %%
df3.plot.scatter(x = 'a', y = 'b',c = 'r', figsize = (15,3),xlim = [-0.2,1.2], ylim = [-0.2,1.2], edgecolors = 'black', linewidths = 2,s = 70)
plt.show()

# %%
df3['a'].plot.hist(xlabel = ('a'),alpha = 0.5 ,bins = 25)
plt.style.use('ggplot')
plt.show()

# %%
df3[['a','b']].plot.box()
plt.show()

# %%
df3['d'].plot.kde(alpha = 0.5, lw = 5, ls = '--')
plt.show()

# %%
ax = df3.head(31).plot.area(alpha = 0.5, figsize = (12,8))
ax.set_ylim([0,3])
ax.set_xlim([0,30])
ax.legend(loc = 'lower right',bbox_to_anchor=(1.1,0.5))
plt.show()
